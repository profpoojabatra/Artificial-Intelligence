# %% [markdown]
# <a href="https://colab.research.google.com/github/profpoojabatra/Artificial-Intelligence/blob/main/Rpaper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers
# !pip install -q sentence-transformers
# !pip install -q PyPDF2
# !pip install -q faiss-cpu
# !pip install -q accelerate
# !pip install -q torch
